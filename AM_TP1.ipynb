# %% [markdown]
# **Cuarteto de Anscombe**
#
# ---
#
#
# Para el análisis tomé los datos originales:
#
#
# ---
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ordeno los datos y calculo los parámetros estadísticos, que resultan consistentes con el enunciado
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Grafico las curvas para tener una referencia visual

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Me piden que considere a que curva corresponde cada uno de estos puntos ([16,8]; [8,6]; [16,10] y [16,6]), manteniendo las constantes estadísticas
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Si analizo las estadísticas de cada figura, y aplico fuerza bruta para contrastar con cada punto, obtengo

# %% [markdown]
# **Para la curva 1**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **curva 2**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# para la curva 3
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# para la curva 4
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***Mirando los números, veo que estadísticamente ni uno de los puntos me permite conservar los parámetros establecidos.***

# %% [markdown]
# en cambio, si ubico manualmente cada punto en la curva **donde visualmente** se acomode mejor al conjunto de datos, se obtiene

# %% [markdown]
# ![image.png]()![image.png](data:image/png;base64,...)

# %% [markdown]
# se ve que los parámetros estadísticos ***son parecidos en entre ellos***, pero no se parecen a los originales

# %% [markdown]
# para la curva 1:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# para la curva 2:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# par ala curva 3:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# para la cruva 4:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Conclusión parcial y dudas:**
# Mas allá de que resulta evidente la necesidad de visualizar los datos y no quedarse sólo con los números, no veo manera de incorporar los puntos propuestos sin alterar las estadísticas iniciales.
# y aquí viene mi consulta: ¿qué se me está escapando? ¿existe algún otro aspecto relevante que no estoy considerando en mi análisis?
#
# Mas que una conclusión definida, tengo dudas sobre cual es la idea subyacente sobre este trabajo y si estoy siguiendo el camino adecuado para completarlo
